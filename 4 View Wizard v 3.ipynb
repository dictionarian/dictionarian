# %%
# Ask the Gurus     11/04/2021        James Johnson 
#
# An aphorism driven "Magic Eight Ball" program 
# 
# This program will emulate a magic eight ball, but it only comes to a conclusion as a result of directed questioning. 
# It cannot actually resolve any real question 
# 
# For best results, don't pay too much attention to the prompts or verbal encouragers the expert gives when you
# say you are not satsified with his answer. Just go right back to what you were talking about, and see where it
# takes you
#
#######################################################################
# Note: as stated at the end of the program, the program writes       #
# a text file called dialogue.txt to disk. If you want to save the    #
# output (whatever the discussion was,) you can change the name of    #
# dialogue.txt to some other name (yourfile.txt.)                     #
# Then the next dialogue.txt doesn't overwrite the script             #
#######################################################################
outfile = open('dialogue.txt', 'w')
import random

Philosopher = ["For a commander to be competent, he must make himself obeyed!", "They change the sky not their soul, who run across the sea!", "I was as you are... as I am, so you will BE!", "I think therefore I am", "Knowledge is Power!", "A soldier is a simple tool!", "The opposite of Salty is Sweet, but the opposite of Sweet MIGHT be Bitter!", "Following the path of least resistance, makes men and rivers crooked.", "If you call for the truth, and then question the answers, only the doubt remains!"] 
Mathematician = ["Well, ANY number divided by 0 is undefined!", "Consider this: 2 + 2 = 5, for very large values of 2!", "Identity, Counting and Addition are axiomatic! Multiplication is NOT!", "True randomness will have occasional order in it. That's why shark attacks aren't evenly distributed over the calendar!", "When you think about it, the square root of two cannot be represented by ANY fraction n/m!", "There are an infinite number of whole numbers, but there are more fractions than that, starting between 0 and 1!", "Ten sided dice are fair, but only if order is not dictated!", "Six sided dice are ALWAYS fair!"] 
Chem_Teacher = ["Sodium and Chlorine are two of the most unstable elements in nature, but Sodium Chloride is possibly the most stable compound known to man!", "The Chemistry of tears is not well investigated!", "Valences of electrons make atoms predictable, but complex molecules still defy analysis!", "Nitroglycerine isn't very stable, even when cotton is dissolved in it!", "You can cook with C4, but don't dare hit it with a hammer while it's burning!", "Liquid Nitrogen cannot be contained!", "Ever try to calculate the impurities of rust?", "Standard Temperature and Pressure allows us to observe that, when pressure goes down, so does temperature, even as low as 200 degrees below zero Celsius!"]
Wisecracker = ["A Bullet cannot tell a lie!", "No matter who calls the shots, a higher power runs the table.", "Even a monkey will fight for its mate!", "A Rising tide raises all boats.", "You think you have problems? Alexander The Great's men wanted him to order back the Tide!", "If you see a sign that says 'Wet Paint,' can you resist the urge to touch it and make sure?", "A rose, by any other name, would smell as sweet.", "A good horse will run until its heart bursts! You can't ask too much of people!", "Some people will ride a horse to death, and then beat it for being DEAD!", "There's a first time for everything!", "Honesty is NOT the best insurance policy!", "There's more ways to skin a cat, than puttin' it's head in a bootjack, and pullin' on its tail!"]
#
#
########################################################################
# Userdefined is an expert that you can use to make up your own wizard #
# Simply delete the "Your imponderable-s- or aphorisms go here.", and  #
# replace it with any wisecrack or comments you would like to see,     #
# quoted, and separated by commas.                                     #
########################################################################
#
#
Userdefined = ["Your imponderable-s- or aphorisms go here."]
#
#
#########################################################################
feedback = ["Sorry to hear that. Could you put it to me another way? ", "Is there another similar question that would clarify your inquiry for me? ", "Maybe that's too complicated a way of asking. How would you phrase your question to a sixth grader? ", "What else can you tell me, that would give me a better idea of your point? ", "How would a person on the opposite side of the debate ask the question? "] 
closing_salutation = ["Have an excellent evening.", "Have a nice day.", "See you next time.", "Keep your chin up!"]
# 
def designated_expert(expert):
    q = input("What conundrum is troubling you today? ") 
    outfile.write("What conundrum is troubling you today? \n")
    outfile.write(q)
    print() 
    outfile.write('\n')
    temp = random.randint(0,len(expert)-1) 
    print(expert[temp])
    outfile.write(expert[temp] + '\n')
    print() 
    outfile.write('\n')
    a = input("Does that just about do it? Y(es) or N(o): ")
    outfile.write("Does that just about do it? Y(es) or N(o): \n")
    outfile.write(a)
    while not(a == "Y" or a == "y" or a == "N" or a == "n"): 
        a = input("Sorry, I didn't follow. Did you mean Y(es) or N(o)?: ")
        outfile.write("Sorry, I didn't follow. Did you mean Y(es) or N(o)?: \n")
        outfile.write(a)
    while(a == "N" or a == "n"): 
        print()
        outfile.write('\n')
        outfile.write('\n')
        temp = random.randint(0, len(feedback)-1) # choose a random number for the index
        hold = input(feedback[temp])              # put the feedback comment in "hold"
        outfile.write(feedback[temp] + '\n')      # write the feedeback comment to disk
        outfile.write(hold + '\n')                # write the keyboard input (question) to disk
        temp = random.randint(0, len(expert)-1)   # choose a random number for reply index
        print()
        print(expert[temp]) 
        outfile.write(expert[temp] + '\n')
        print()
        outfile.write('\n')
        a = input("Does that just about do it? Y(es) or N(o): ")
        outfile.write("Does that just about do it? Y(es) or N(o): \n")
        outfile.write(a)
        while not(a == "Y" or a == "y" or a == "N" or a == "n"): 
            a = input("Sorry, I didn't follow. Did you mean Y(es) or N(o)?: ")
            outfile.write("Sorry, I didn't follow. Did you mean Y(es) or N(o)?: \n")
            outfile.write(a)
#           
def choose(tempstring):
    number = 0
    if(tempstring == "1"):
        number = 1
    elif(tempstring == "2"):
        number = 2
    elif(tempstring == "3"):
        number = 3
    elif(tempstring == "4"):
        number = 4
    elif(tempstring == "5"):
        number = 5
    elif(tempstring == "6"):
        number = 6
    else:
        number = 0
    return number
#
def wizard():
    print()
    outfile.write('\n')
    print()
    outfile.write('\n')
    print()
    outfile.write('\n')
    print("Hello. I'm the Receptionist.") 
    outfile.write("Hello. I'm the Receptionist.\n")
    print() 
    outfile.write('\n')
    print("Who would you like to talk to?")
    outfile.write("Who would you like to talk to?\n")
    print()
    outfile.write('\n')
    print("1. The Philospher")
    outfile.write("1. The Philosopher\n")
    print("2. The Mathematician")
    outfile.write("2. The Mathematician\n")
    print("3. The Chem Teacher")
    outfile.write("3. The Chem Teacher\n")
    print("4. The Wisecracker")
    outfile.write("4. The Wisecracker\n")
    print("5. The unknown -user defined- expert")
    outfile.write("5. The unknown -user defined- expert")
    print("6. You've changed your mind, and just want to leave: ")
    outfile.write("6. You've changed your mind, and just want to leave: \n")
    print()
    outfile.write('\n')
    hold1 = input("Enter 1, 2, 3, 4, 5 or 6: ")
    outfile.write("Enter 1, 2, 3, 4, 5 or 6: \n")
    outfile.write(hold1)
    choice = choose(hold1)
    random.seed()
    while not(choice == 1 or choice == 2 or choice == 3 or choice == 4 or choice == 5 or choice == 6):
        print()
        outfile.write('\n')
        hold1 = (input("Enter 1, 2, 3, 4, 5 or 6: "))
        outfile.write("Enter 1, 2, 3, 4, 5 or 6: \n")
        outfile.write(hold1)
        choice = choose(hold1)
    if(choice == 1):
        engine = Philosopher
    elif(choice == 2):
        engine = Mathematician
    elif(choice == 3):
        engine = Chem_Teacher
    elif(choice == 4):
        engine = Wisecracker
    elif(choice == 5):
        engine = Userdefined
    else:
        print()
        outfile.write('\n')
    #
    if(choice == 1):
        print()
        outfile.write('\n')
        print()
        outfile.write('\n')
        print("Hi. I'm the resident philosopher - not a PhD mind you, but I'll do my best to give you")
        outfile.write("Hi. I'm the resident philosopher - not a PhD mind you, but I'll do my best to give you\n")
        print("a philospher's point of view.")
        outfile.write("a philospher's point of view.\n")
        print()
        outfile.write('\n')
        designated_expert(engine)
    elif(choice == 2):
        print()
        outfile.write('\n')
        print()
        outfile.write('\n')
        print("Hello, and nice to meet you: I'm the math teacher, and I'll be helping you see how a")
        outfile.write("Hello, and nice to meet you: I'm the math teacher, and I'll be helping you see how a\n")
        print("mathematician might offer suggestions on how to solve your proplem: ")
        outfile.write("mathematician might offer suggestions on how to solve your proplem: \n")
        print()
        outfile.write('\n')
        designated_expert(engine)
    elif(choice == 3):
        print()
        outfile.write('\n')
        print()
        outfile.write('\n')
        print("Greetings and salutations. I'm the Chem Teacher, and I'm here to give you a Chemistry Professor's take")
        outfile.write("Greetings and salutations. I'm the Chem Teacher, and I'm here to give you a Chemistry Professor's take\n")
        print("on any discussion you want to have. Chemistry isn't all youthful hormones, you know!")
        outfile.write("on any discussion you want to have. Chemistry isn't all youthful hormones, you know!\n")
        print()
        outfile.write('\n')
        designated_expert(engine)
    elif(choice == 4):
        print()
        outfile.write('\n')
        print()
        outfile.write('\n')
        print("What's up stranger? I hear you've got questions even the experts can't answer!")
        outfile.write("What's up stranger? I hear you've got questions even the experts can't answer!\n")
        print("Well, I've got you covered; tell me how I can help:")
        outfile.write("Well, I've got you covered; tell me how I can help:\n")
        print()
        outfile.write('\n')
        designated_expert(engine)
    elif(choice == 5):
        print()
        outfile.write('\n')
        print()
        outfile.write('\n')
        print("I'm not the first choice here, but I have ideas of my own!")
        outfile.write("I'm not the first choice here, but I have ideas of my own!",'\n')
        print("Ask me anything! Ask me! Ask me!")
        outfile.write("Ask me anything! Ask me! Ask me!",'\n')
        print()
        outfile.write('\n')
        designated_expert(engine)
    else:
        print()
        outfile.write('\n')
        print("Well it's been nice talking to you then.")
        outfile.write("Well it's been nice talking to you then.\n")
    print()
    outfile.write('\n')
    temp = random.randint(0, len(closing_salutation)-1)
    print(closing_salutation[temp])
    outfile.write(closing_salutation[temp] + '\n')
    print()
    outfile.write('\n')
    print()
    outfile.write('\n')
    outfile.close()
    print("Your output is saved in a file called dialogue.txt")
    print("Be sure and change the name, if you want to save the dialogue.")
    input("Hit <enter> to end.")
    #
#
wizard()
# Out:
# Hello. I'm the Receptionist.
#
# Who would you like to talk to?
#
# 1. The Philospher
# 2. The Mathematician
# 3. The Chem Teacher
# 4. The Wisecracker
# 5. The unknown -user defined- expert
# 6. You've changed your mind, and just want to leave:
#
# Enter 1, 2, 3, 4, 5 or 6: 6
#
#
# Well it's been nice talking to you then.
#
# Keep your chin up!
#
#
# Your output is saved in a file called dialogue.txt
# Be sure and change the name, if you want to save the dialogue.
# Hit <enter> to end.
